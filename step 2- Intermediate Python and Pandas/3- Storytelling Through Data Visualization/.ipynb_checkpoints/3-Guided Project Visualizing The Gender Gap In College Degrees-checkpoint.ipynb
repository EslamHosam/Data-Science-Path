# %% [markdown]
# # Visualizing The Gender Gap In College Degrees
# - In this guided project, we'll extend the work we did in the last two missions on visualizing the gender gap across college degrees. So far, we mostly focused on the STEM degrees but now we will generate line charts to compare across all degree categories. In the last step of this guided project, we'll explore how to export the final diagram we create as an image file

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# - Because there are seventeen degrees that we need to generate line charts for, we'll use a subplot grid layout of 6 rows by 3 columns. We can then group the degrees into STEM, liberal arts, and other, in the following way:

# %% [markdown]
# stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
#
# lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance',
#                  'Social Sciences and History']
#
# other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %% [markdown]
# - While in the last mission, the stem_cats list was ordered by ending gender gap, all three of these lists are ordered in descending order by the percentage of degrees awarded to women. You may have also noticed that while stem_cats and other_cats have six degree categories as elements, lib_arts_cats only has five. You'll need to not only modify the for loop to generate the STEM line charts that we wrote in the last mission but also add two new for loops to generate the line charts for liberal arts degrees and for other degrees.

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']

lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
# Generate a 6 row by 3 column grid of subplots.
fig = plt.figure(figsize= (18, 22))

#plot for stem_cats 
# NOTE here we want to display the stem_cats in the first column in the subplot matrix locations (1,4,7,13,16)
# so in the subplot for plot number put ((3*i) +1) to plot in these postions
for i in range(0,6):
    ax = fig.add_subplot(6,3, (3*i)+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c = cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[stem_cats[i]], c = cb_orange, linewidth= 2.5)
    ax.set_title(stem_cats[i])
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom=False, top= False, left= False, right= False)
#     if i == 0 :
#         ax.text(2010, 87, "women")
#         ax.text(2010, 8, "men")


# for lib_arts , ((3*i) +1) for positions in the grid
for i in range(0,5):
    ax = fig.add_subplot(6,3, (3*i) +2)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c = cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[lib_arts_cats[i]], c = cb_orange, linewidth= 2.5)
    ax.set_title(stem_cats[i])
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom=False, top= False, left= False, right= False)
#     if i == 0 :
#         ax.text(2010, 87, "women")
#         ax.text(2010, 8, "men")

# for otjer cats, (3*i) +3 for positions
for i in range(0,6):
    ax = fig.add_subplot(6,3, (3*i) +3)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c = cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[other_cats[i]], c = cb_orange, linewidth= 2.5)
    ax.set_title(stem_cats[i])
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.tick_params(bottom=False, top= False, left= False, right= False)
#     if i == 0 :
#         ax.text(2010, 87, "women")
#         ax.text(2010, 8, "men")

plt.show()

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']

lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize = (18,26))

# FOR THE FIRST LIST
for i in range(len(stem_cats)):
    ax = fig.add_subplot(6,3, (3*i)+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[stem_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[i])
    # set text 
    if i == 0:
        ax.text(2011,20, "Men")
        ax.text(2011,80, "Women")
        
    
# for the second list
for i in range(len(lib_arts_cats)):
    ax = fig.add_subplot(6,3, (3*i) +2)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[lib_arts_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[i])
    

#for the last one
for i in range(len(other_cats)):
    ax = fig.add_subplot(6,3,(3*i) +3)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[other_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[i])
    # add text and last x axis labels
    if i == 5:
        ax.text(2011,30, "Women")
        ax.text(2011,68, "Men")
        
    
plt.show()

# %% [markdown]
# ### hiding x-axis labels

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']

lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize = (18,22))

# FOR THE FIRST LIST
for i in range(len(stem_cats)):
    ax = fig.add_subplot(6,3, (3*i)+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[stem_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[i])
    # set text and display x-axis for last plot
    if i == 0:
        ax.text(2011,20, "Men")
        ax.text(2011,80, "Women")
    elif i == 5:
        ax.tick_params(labelbottom = True)
        
    
# for the second list
for i in range(len(lib_arts_cats)):
    ax = fig.add_subplot(6,3, (3*i) +2)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[lib_arts_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[i])
    # display x-axis label for last plot
    if i == 4:
        ax.tick_params(labelbottom = True)
    

#for the last one
for i in range(len(other_cats)):
    ax = fig.add_subplot(6,3,(3*i) +3)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[other_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[i])
    # add text and last x axis labels
    if i == 5:
        ax.text(2011,30, "Women")
        ax.text(2011,68, "Men")
        ax.tick_params(labelbottom = True)
        
    
plt.show()

# %% [markdown]
# ### setting the y axis labels

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']

lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize = (18,22))

# FOR THE FIRST LIST
for i in range(len(stem_cats)):
    ax = fig.add_subplot(6,3, (3*i)+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[stem_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[i])
    #set y axis labels at 0 to 100
    ax.set_yticks([0,100])
    
    # set text and display x-axis for last plot
    if i == 0:
        ax.text(2011,20, "Men")
        ax.text(2011,80, "Women")
    elif i == 5:
        ax.tick_params(labelbottom = True)
        
    
# for the second list
for i in range(len(lib_arts_cats)):
    ax = fig.add_subplot(6,3, (3*i) +2)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[lib_arts_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[i])
    ax.set_yticks([0,100])
    # display x-axis label for last plot
    if i == 4:
        ax.tick_params(labelbottom = True)
    

#for the last one
for i in range(len(other_cats)):
    ax = fig.add_subplot(6,3,(3*i) +3)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[other_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[i])
    ax.set_yticks([0,100])
    # add text and last x axis labels
    if i == 5:
        ax.text(2011,30, "Women")
        ax.text(2011,68, "Men")
        ax.tick_params(labelbottom = True)
        
    
plt.show()

# %% [markdown]
# ### adding horizntal line
# - We can generate a horizontal line across an entire subplot using the Axes.axhline() method. The only required parameter is the y-axis location for the start of the line:

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']

lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance',
                 'Social Sciences and History']

other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize = (18,22))

# FOR THE FIRST LIST
for i in range(len(stem_cats)):
    ax = fig.add_subplot(6,3, (3*i)+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[stem_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[i])
    #set y axis labels at 0 to 100
    ax.set_yticks([0,100])
    # adding horizntal line
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.5)
    
    # set text and display x-axis for last plot
    if i == 0:
        ax.text(2011,20, "Men")
        ax.text(2011,80, "Women")
    elif i == 5:
        ax.tick_params(labelbottom = True)
        
    
# for the second list
for i in range(len(lib_arts_cats)):
    ax = fig.add_subplot(6,3, (3*i) +2)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[lib_arts_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[i])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    # display x-axis label for last plot
    if i == 4:
        ax.tick_params(labelbottom = True)
    

#for the last one
for i in range(len(other_cats)):
    ax = fig.add_subplot(6,3,(3*i) +3)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[i]], c= cb_dark_blue, linewidth = 2.5 )
    ax.plot(women_degrees["Year"], 100 - women_degrees[other_cats[i]], c =cb_orange, linewidth = 2.5 )
    #hiding spines
    for key, spin in ax.spines.items():
        spin.set_visible(False)
    #hiding ticks
    ax.tick_params(bottom=False, top= False, left= False, right= False, labelbottom = False)
    
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[i])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    # add text and last x axis labels
    if i == 5:
        ax.text(2011,30, "Women")
        ax.text(2011,68, "Men")
        ax.tick_params(labelbottom = True)
        
    
plt.show()

# %% [markdown]
# ### Exporting the graph to a file

# %%
plt.savefig("all degrees gender gap.png")
